# %%
# Set up Revise.jl for automatic code reloading
# This only needs to be run once at the beginning of your notebook session
using Revise
using DrWatson

# Activate the project using absolute path (more reliable in notebooks than @__DIR__)
quickactivate(@__DIR__, "Math_Foundations")

# Load the package 
using Math_Foundations

# %%
# Example usage
println(fibonacci_iterative(10))  # Outputs: 55
# Out:
# 55
